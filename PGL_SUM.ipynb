# %%
# !git clone https://github.com/hcmus-thesis-gulu/PGL-SUM.git
# Out:
# Cloning into 'PGL-SUM'...
# remote: Enumerating objects: 201, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 201 (delta 50), reused 31 (delta 30), pack-reused 142
# Receiving objects: 100% (201/201), 91.79 MiB | 6.35 MiB/s, done.
# Resolving deltas: 100% (95/95), done.

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 KB 2.3 MB/s eta 0:00:00
# ...

# %%
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 1), reused 3 (delta 1), pack-reused 0
# Unpacking objects: 100% (3/3), 353 bytes | 353.00 KiB/s, done.
# From https://github.com/feenix-ho/PGL-SUM
#    81d0d6d..0ffa717  master     -> origin/master
# Updating 81d0d6d..0ffa717
# Fast-forward
#  .../SumMe/eccv16_dataset_summe_google_pool5.rar    | Bin 0 -> 22375402 bytes
#  .../TVSum/eccv16_dataset_tvsum_google_pool5.rar    | Bin 0 -> 73783573 bytes
#  data/datasets/splits/summe_splits.json             | 157 ++++++++++++
#  data/datasets/splits/tvsum_splits.json             | 282 +++++++++++++++++++++
#  4 files changed, 439 insertions(+)
#  create mode 100644 data/datasets/SumMe/eccv16_dataset_summe_google_pool5.rar
#  create mode 100644 data/datasets/TVSum/eccv16_dataset_tvsum_google_pool5.rar
#  create mode 100644 data/datasets/splits/summe_splits.json
# ...

# %%
# %cd /content/PGL-SUM/data/SumMe
# !unrar e eccv16_dataset_summe_google_pool5.rar
# Out:
# /content/PGL-SUM/data/datasets/SumMe
#
# UNRAR 5.61 beta 1 freeware      Copyright (c) 1993-2018 Alexander Roshal
#
#
# Extracting from eccv16_dataset_summe_google_pool5.rar
#
#   OK
# All OK

# %%
# %cd /content/PGL-SUM/data/TVSum
# !unrar e eccv16_dataset_tvsum_google_pool5.rar
# Out:
# /content/PGL-SUM/data/datasets/TVSum
#
# UNRAR 5.61 beta 1 freeware      Copyright (c) 1993-2018 Alexander Roshal
#
#
# Extracting from eccv16_dataset_tvsum_google_pool5.rar
#
#   OK
# All OK

# %%
# %cd /content/PGL-SUM
# Out:
# /content/PGL-SUM

# %%
# !python model/main.py --split_index 0 --n_epochs 100 --batch_size 16 --video_type 'SumMe'
# Out:
# Configurations
# {'batch_size': 16,
#  'clip': 5.0,
#  'device': device(type='cuda', index=0),
#  'fusion': 'add',
#  'heads': 8,
#  'init_gain': None,
#  'init_type': 'xavier',
#  'input_size': 1024,
#  'l2_req': 1e-05,
#  'log_dir': PosixPath('../PGL-SUM/Summaries/PGL-SUM/exp1/SumMe/logs/split0'),
#  'lr': 5e-05,
#  'mode': 'train',
#  'n_epochs': 100,
#  'n_segments': 4,
#  'pos_enc': 'absolute',
#  'save_dir': PosixPath('../PGL-SUM/Summaries/PGL-SUM/exp1/SumMe/models/split0'),
#  'score_dir': PosixPath('../PGL-SUM/Summaries/PGL-SUM/exp1/SumMe/results/split0'),
#  'seed': 12345,
#  'split_index': 0,
#  'verbose': False,
#  'video_type': 'SumMe'}
# Configurations
# {'batch_size': 16,
#  'clip': 5.0,
#  'device': device(type='cuda', index=0),
#  'fusion': 'add',
#  'heads': 8,
#  'init_gain': None,
#  'init_type': 'xavier',
#  'input_size': 1024,
#  'l2_req': 1e-05,
#  'log_dir': PosixPath('../PGL-SUM/Summaries/PGL-SUM/exp1/SumMe/logs/split0'),
#  'lr': 5e-05,
#  'mode': 'test',
# ...
